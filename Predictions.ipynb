# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('prices-split-adjusted.csv')
data
# Out:
#               date symbol        open       close         low        high  \
# 0       2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000
# 1       2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001
# 2       2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998
# 3       2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002
# 4       2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002
# ...            ...    ...         ...         ...         ...         ...
# 851259  2016-12-30    ZBH  103.309998  103.199997  102.849998  103.930000
# 851260  2016-12-30   ZION   43.070000   43.040001   42.689999   43.310001
# 851261  2016-12-30    ZTS   53.639999   53.529999   53.270000   53.740002
# 851262  2016-12-30    AIV   44.730000   45.450001   44.410000   45.590000
# 851263  2016-12-30    FTV   54.200001   53.630001   53.389999   54.480000
#
#            volume
# 0       2163600.0
# 1       2386400.0
# 2       2489500.0
# ...

# %%
data.describe()
# Out:
#                 open          close            low           high  \
# count  851264.000000  851264.000000  851264.000000  851264.000000
# mean       64.993618      65.011913      64.336541      65.639748
# std        75.203893      75.201216      74.459518      75.906861
# min         1.660000       1.590000       1.500000       1.810000
# 25%        31.270000      31.292776      30.940001      31.620001
# 50%        48.459999      48.480000      47.970001      48.959999
# 75%        75.120003      75.139999      74.400002      75.849998
# max      1584.439941    1578.130005    1549.939941    1600.930054
#
#              volume
# count  8.512640e+05
# mean   5.415113e+06
# std    1.249468e+07
# min    0.000000e+00
# 25%    1.221500e+06
# 50%    2.476250e+06
# 75%    5.222500e+06
# max    8.596434e+08

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851264 entries, 0 to 851263
# Data columns (total 7 columns):
# date      851264 non-null object
# symbol    851264 non-null object
# open      851264 non-null float64
# close     851264 non-null float64
# low       851264 non-null float64
# high      851264 non-null float64
# volume    851264 non-null float64
# dtypes: float64(5), object(2)
# memory usage: 45.5+ MB

# %%
nflx = data[data['symbol'] == 'NFLX']
nflx
# Out:
#               date symbol        open       close         low        high  \
# 555     2010-01-04   NFLX    7.931428    7.640000    7.565714    7.961429
# 1023    2010-01-05   NFLX    7.652857    7.358572    7.258572    7.657143
# 1491    2010-01-06   NFLX    7.361429    7.617143    7.197143    7.672857
# 1959    2010-01-07   NFLX    7.731429    7.485714    7.462857    7.757143
# 2427    2010-01-08   NFLX    7.498571    7.614286    7.465714    7.742857
# ...            ...    ...         ...         ...         ...         ...
# 849088  2016-12-23   NFLX  125.610001  125.589996  125.080002  126.279999
# 849588  2016-12-27   NFLX  126.239998  128.350006  125.699997  129.050003
# 850088  2016-12-28   NFLX  129.070007  125.889999  125.760002  129.070007
# 850588  2016-12-29   NFLX  125.949997  125.330002  124.199997  126.139999
# 851088  2016-12-30   NFLX  126.239998  123.800003  123.599998  126.570000
#
#             volume
# 555     17239600.0
# 1023    23753100.0
# ...

# %%
googl = data[data['symbol'] == 'GOOGL']
googl
# Out:
#               date symbol        open       close         low        high  \
# 440     2010-01-04  GOOGL  313.788792  313.688694  312.432438  315.070073
# 908     2010-01-05  GOOGL  313.903904  312.307316  311.081089  314.234226
# 1376    2010-01-06  GOOGL  313.243260  304.434452  303.483494  313.243260
# 1844    2010-01-07  GOOGL  305.005009  297.347355  296.621617  305.305302
# 2312    2010-01-08  GOOGL  296.296299  301.311314  294.849857  301.926945
t.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
plt.plot(aapl.open.values, color='red', label='open')
plt.plot(aapl.close.values, color='green', label='close')
plt.plot(aapl.low.values, color='brown', label='low')
plt.plot(aapl.high.values, color='blue', label='high')
plt.title('Apple Stock')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend(loc='best')

plt.subplot(1, 2, 2)
plt.plot(aapl.volume.values, color='black', label='volume')
plt.xlabel('Time')
plt.ylabel('Volume')
plt.title('Apple Volume')
# Out:
# Text(0.5, 1.0, 'Apple Volume')

# %%
fig = plt.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
plt.plot(nflx.open.values, color='red', label='open')
plt.plot(nflx.close.values, color='green', label='close')
plt.plot(nflx.low.values, color='brown', label='low')
plt.plot(nflx.high.values, color='blue', label='high')
plt.title('Netflix Stock')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend(loc='best')

plt.subplot(1, 2, 2)
plt.plot(nflx.volume.values, color='black', label='volume')
plt.xlabel('Time')
plt.ylabel('Volume')
plt.title('Netflix Volume')
# Out:
# Text(0.5, 1.0, 'Netflix Volume')

# %%
fig = plt.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
plt.plot(fb.open.values, color='red', label='open')
plt.plot(fb.close.values, color='green', label='close')
plt.plot(fb.low.values, color='brown', label='low')
plt.plot(fb.high.values, color='blue', label='high')
plt.title('facebook Stock')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend(loc='best')

plt.subplot(1, 2, 2)
plt.plot(fb.volume.values, color='black', label='volume')
plt.xlabel('Time')
plt.ylabel('Volume')
plt.title('Facebook Volume')
# Out:
# Text(0.5, 1.0, 'Facebook Volume')

# %%
fig = plt.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
plt.plot(googl.open.values, color='red', label='open')
plt.plot(googl.close.values, color='green', label='close')
plt.plot(googl.low.values, color='brown', label='low')
plt.plot(googl.high.values, color='blue', label='high')
plt.title('Google Stock')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend(loc='best')

plt.subplot(1, 2, 2)
plt.plot(googl.volume.values, color='black', label='volume')
plt.xlabel('Time')
plt.ylabel('Volume')
plt.title('Google Volume')
# Out:
# Text(0.5, 1.0, 'Google Volume')

# %%
fig = plt.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
plt.plot(amzn.open.values, color='red', label='open')
plt.plot(amzn.close.values, color='green', label='close')
plt.plot(amzn.low.values, color='brown', label='low')
plt.plot(amzn.high.values, color='blue', label='high')
plt.title('Amazon Stock')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend(loc='best')

plt.subplot(1, 2, 2)
plt.plot(amzn.volume.values, color='black', label='volume')
plt.xlabel('Time')
plt.ylabel('Volume')
plt.title('Amazon Volume')
# Out:
# Text(0.5, 1.0, 'Amazon Volume')

# %%
x = aapl[['open', 'low', 'high', 'volume']].values
y = aapl['close'].values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=100)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred = lm.predict(x_test)
result = pd.DataFrame({'Actual ':y_test, 'Predicted':pred})
result
# Out:
#         Actual    Predicted
# 0     32.985714   33.022125
# 1     28.990000   29.004453
# 2     37.630001   37.561079
# 3     61.680000   61.775174
# 4    128.460007  129.094935
# ..          ...         ...
# 348   74.365715   74.065531
# 349   48.297142   48.348699
# 350   65.712860   65.267015
# 351   88.701431   88.688136
# 352   64.261429   64.179961
#
# [353 rows x 2 columns]

# %%
fig = plt.figure(figsize=(30,15))
g = result.head(50)
g.plot(kind='bar')

# %%
df = aapl[['close']]
df.head()
# Out:
#           close
# 254   30.572857
# 721   30.625713
# 1189  30.138571
# 1657  30.082857
# 2125  30.282858

# %%
future_days = 50
df['Prediction'] = df[['close']].shift(-future_days)
df.tail()
# Out:
# C:\Users\Aditya\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              close  Prediction
# 848767  116.519997         NaN
# 849267  117.260002         NaN
# 849767  116.760002         NaN
# 850267  116.730003         NaN
# 850767  115.820000         NaN

# %%
r = np.array(df.drop(['Prediction'], 1))[:-future_days]
print(r)
# Out:
# [[ 30.57285686]
#  [ 30.62571329]
#  [ 30.13857071]
#  ...
#  [117.550003  ]
#  [117.470001  ]
#  [117.120003  ]]

# %%
e = np.array(df['Prediction'])[:future_days]
print(e)
# Out:
# [32.01714329 32.09285743 31.75       32.10714343 32.62285614 32.76714329
#  32.37857057 32.985714   33.19857029 33.69285586 33.57143014 33.70999914
#  34.06999971 34.22000129 34.37142943 34.27857214 34.54142757 34.61285786
#  34.63285829 35.09857171 35.56000143 35.34285743 35.29571529 34.94142914
#  37.03142929 38.06714243 38.68999857 38.5        37.43428414 37.37142943
#  38.37714386 37.29857257 38.04999929 36.95428471 36.56999971 35.17856986
#  33.69428629 36.28428643 36.64571386 37.44142914 36.90857314 36.25999829
#  36.31714243 36.05142971 35.47714229 33.96571357 34.61714171 35.25142671
#  35.03142929 34.87285614]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

# %%
x_future = df.drop(['Prediction'], 1)[:-future_days]
x_future = x_future.tail(future_days)
x_future = np.array(x_future)
x_future
# Out:
# array([[108.      ],
#        [107.93    ],
#        [108.18    ],
#        [109.480003],
#        [109.379997],
#        [109.220001],
#        [109.080002],
#        [109.360001],
#        [108.510002],
#        [108.849998],
#        [108.029999],
#        [107.57    ],
#        [106.940002],
#        [106.82    ],
#        [106.      ],
#        [106.099998],
#        [106.730003],
#        [107.730003],
#        [107.699997],
#        [108.360001],
#        [105.519997],
#        [103.129997],
#        [105.440002],
#        [107.949997],
#        [111.769997],
#        [115.57    ],
#        [114.919998],
#        [113.580002],
#        [113.57    ],
#        [113.550003],
#        [114.620003],
#        [112.709999],
#        [112.879997],
#        [113.089996],
#        [113.949997],
#        [112.18    ],
#        [113.050003],
#        [112.519997],
#        [113.      ],
#        [113.050003],
#        [113.889999],
#        [114.059998],
#        [116.050003],
# ...

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr_pred = lr.predict(x_test)
lr_pred
# Out:
# array([100.1745399 , 118.99651726,  71.42210319,  89.74482738,
#         55.26131927,  82.88429496,  92.94032717,  53.46455598,
#        127.0403634 , 100.90417095,  51.17319315,  87.21517744,
#        113.1307694 ,  47.02257211, 118.25950079,  48.53629136,
#         83.99844144,  95.3099523 ,  95.595998  , 111.37063143,
#         84.41933345,  45.95283534, 100.16168574,  78.05708578,
#         48.3343392 ,  57.62316203,  87.30370279,  51.05538485,
#         71.9754259 ,  44.035626  , 117.61226859,  97.47175857,
#         99.73111874,  93.42193401,  35.00353771,  37.69185833,
#         94.07566868,  37.53754667, 101.19842062,  29.2033844 ,
#         78.6126573 ,  61.87095552,  71.64223908, 108.61404102,
#         99.16624417,  66.65205093, 101.93769559,  37.46822333,
#         38.51545017,  35.20159503,  49.66911907,  77.52908639,
#        108.98927104,  29.64700414,  61.81856191,  54.39325499,
#         40.55014107, 100.11899408,  72.64458149,  74.38268868,
# ...

# %%
predi = lr_pred

valid = aapl[x.shape[0]:]
valid['Prediction'] = predi
plt.figure(figsize=(17,8))
plt.title('Model')
plt.xlabel('Days')
plt.ylabel('Close price in USD')
plt.plot(aapl['close'])
plt.plot(valid[['close', 'Prediction']])
plt.legend(['Pred', 'Val', 'Orig'])
plt.show()
# Out:
# C:\Users\Aditya\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
